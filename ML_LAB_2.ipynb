# %%
import pandas as pd
import numpy as np


df = pd.read_excel(r"19CSE305_LabData_Set3.1.xlsx", sheet_name='thyroid0387_UCI',na_values='?')

nominal=['sex', 'on thyroxine', 'query on thyroxine',
       'on antithyroid medication', 'sick', 'pregnant', 'thyroid surgery',
       'I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium',
       'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured', 
       'T3 measured', 'TT4 measured', 'T4U measured',
       'FTI measured', 'TBG measured', 'referral source',
       'Condition']

nominalencoded = pd.get_dummies(df,columns=nominal)
df=nominalencoded
df
# Out:
#      Record ID  age   TSH   T3    TT4   T4U    FTI   TBG  sex_F  sex_M  ...  \
# 0    840801013   29   0.3  NaN    NaN   NaN    NaN   NaN   True  False  ...
# 1    840801014   29   1.6  1.9  128.0   NaN    NaN   NaN   True  False  ...
# 2    840801042   41   NaN  NaN    NaN   NaN    NaN  11.0   True  False  ...
# 3    840803046   36   NaN  NaN    NaN   NaN    NaN  26.0   True  False  ...
# 4    840803047   32   NaN  NaN    NaN   NaN    NaN  36.0   True  False  ...
# ..         ...  ...   ...  ...    ...   ...    ...   ...    ...    ...  ...
# 995  841031002   41   0.1  2.1  148.0  1.44  103.0   NaN   True  False  ...
# 996  841031010   41  53.0  0.4    9.7  1.46    6.6   NaN   True  False  ...
# 997  841031030   20   NaN  NaN    NaN   NaN    NaN  30.0   True  False  ...
# 998  841031031   20   0.1  0.8  201.0  0.84  240.0   NaN   True  False  ...
# 999  841031032   73   3.3  1.2   85.0  0.90   94.0   NaN   True  False  ...
#
# ...

# %%
import numpy as np

Q3 = df['TSH'].quantile(0.75)
Q1 = df['TSH'].quantile(0.25)
IQR = Q3 - Q1

upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

outliers_TSH =df[(df['TSH'] < lower_bound) | (df['TSH'] > upper_bound)]
outliers_TSH
# Out:
#      Record ID  age         TSH   T3    TT4   T4U    FTI  TBG  sex_F  sex_M  \
# 18   840815067   63   68.000000  NaN   48.0  1.02   47.0  NaN   True  False
# 22   840816002   40    5.900000  2.1   88.0  0.84  105.0  NaN   True  False
# 39   840816047   55    9.599999  2.4  136.0  1.48   92.0  NaN   True  False
# 43   840816061   41  140.000000  NaN   33.0  1.07   31.0  NaN   True  False
# 53   840816095   59    6.800000  2.5   94.0  1.40   68.0  NaN   True  False
# ..         ...  ...         ...  ...    ...   ...    ...  ...    ...    ...
# 950  841025079   42    6.600000  NaN   89.0  0.95   94.0  NaN   True  False
# 954  841026014   65    5.900000  1.8   98.0  1.16   98.0  NaN   True  False
# 960  841026061   68    5.100000  NaN   98.0  1.00   98.0  NaN   True  False
# 974  841029023   32  150.000000  0.4   16.0  0.95   17.0  NaN  False   True
# 996  841031010   41   53.000000  0.4    9.7  1.46    6.6  NaN   True  False
#
# ...

# %%
Q3 = df['T3'].quantile(0.75)
Q1 = df['T3'].quantile(0.25)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

outliers_T3 =df[(df['T3'] < lower_bound) | (df['T3'] > upper_bound)]
outliers_T3
# Out:
#      Record ID  age     TSH        T3    TT4   T4U    FTI  TBG  sex_F  sex_M  \
# 31   840816011   85    0.05  0.100000   47.0  0.68   69.0  NaN  False   True
# 107  840822023   28    0.20  3.700000  170.0  1.83   93.0  NaN   True  False
# 117  840823002   83    0.90  4.400000  144.0  1.44  100.0  NaN   True  False
# 149  840823092   26    0.60  3.600000  150.0  1.56   96.0  NaN   True  False
# 151  840824001   58     NaN  7.600000  250.0  0.79  316.0  NaN   True  False
# 199  840829021   57    0.25  4.200000  236.0  0.70  337.0  NaN  False   True
# 254  840903084   27    6.00  3.800000  149.0  1.73   86.0  NaN   True  False
# 348  840910056   58    0.30  4.100000  202.0  0.80  253.0  NaN   True  False
# 354  840911020   62    0.30  6.600000  169.0  0.86  197.0  NaN   True  False
# 367  840912001   34    0.30  4.700000  242.0  1.02  237.0  NaN  False   True
# 372  840913004   31    1.80  3.700000  109.0  1.62   67.0  NaN   True  False
# ...

# %%
Q3 = df['T4U'].quantile(0.75)
Q1 = df['T4U'].quantile(0.25)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

outliers_T4U =df[(df['T4U'] < lower_bound) | (df['T4U'] > upper_bound)]
outliers_T4U
# Out:
#      Record ID  age         TSH   T3    TT4   T4U    FTI  TBG  sex_F  sex_M  \
# 33   840816014   71    0.050000  NaN  126.0  1.38   91.0  NaN   True  False
# 36   840816028   51    1.200000  2.1  104.0  1.57   66.0  NaN   True  False
# 39   840816047   55    9.599999  2.4  136.0  1.48   92.0  NaN   True  False
# 53   840816095   59    6.800000  2.5   94.0  1.40   68.0  NaN   True  False
# 107  840822023   28    0.200000  3.7  170.0  1.83   93.0  NaN   True  False
# 117  840823002   83    0.900000  4.4  144.0  1.44  100.0  NaN   True  False
# 149  840823092   26    0.600000  3.6  150.0  1.56   96.0  NaN   True  False
# 169  840827025   18   11.599999  2.0   87.0  0.32  272.0  NaN  False  False
# 170  840827028   18    4.200000  0.9   84.0  0.32  263.0  NaN  False  False
# 186  840828034   49    2.200000  0.8   27.0  0.52   52.0  NaN   True  False
# 218  840830045   24   16.500000  NaN  106.0  1.51   70.0  NaN   True  False
# ...

# %%
Q3 = df['FTI'].quantile(0.75)
Q1 = df['FTI'].quantile(0.25)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

outliers_FTI =df[(df['FTI'] < lower_bound) | (df['FTI'] > upper_bound)]
outliers_FTI
# Out:
#      Record ID  age    TSH   T3    TT4   T4U    FTI  TBG  sex_F  sex_M  ...  \
# 43   840816061   41  140.0  NaN   33.0  1.07   31.0  NaN   True  False  ...
# 79   840820014   27   90.0  0.4    7.5  0.94    7.5  NaN   True  False  ...
# 100  840821049   38    NaN  NaN  308.0  0.87  354.0  NaN  False   True  ...
# 136  840823044   68    0.1  1.8  196.0  0.92  213.0  NaN   True  False  ...
# 151  840824001   58    NaN  7.6  250.0  0.79  316.0  NaN   True  False  ...
# ..         ...  ...    ...  ...    ...   ...    ...  ...    ...    ...  ...
# 972  841029020   55    0.1  NaN  196.0  0.94  208.0  NaN   True  False  ...
# 974  841029023   32  150.0  0.4   16.0  0.95   17.0  NaN  False   True  ...
# 991  841030049   62    0.1  1.5  198.0  0.94  211.0  NaN   True  False  ...
# 996  841031010   41   53.0  0.4    9.7  1.46    6.6  NaN   True  False  ...
# 998  841031031   20    0.1  0.8  201.0  0.84  240.0  NaN   True  False  ...
#
# ...

# %%
Q3 = df['TT4'].quantile(0.75)
Q1 = df['TT4'].quantile(0.25)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

outliers_TT4 =df[(df['TT4'] < lower_bound) | (df['TT4'] > upper_bound)]
outliers_TT4
# Out:
#      Record ID  age     TSH   T3    TT4   T4U    FTI  TBG  sex_F  sex_M  ...  \
# 79   840820014   27   90.00  0.4    7.5  0.94    7.5  NaN   True  False  ...
# 100  840821049   38     NaN  NaN  308.0  0.87  354.0  NaN  False   True  ...
# 136  840823044   68    0.10  1.8  196.0  0.92  213.0  NaN   True  False  ...
# 151  840824001   58     NaN  7.6  250.0  0.79  316.0  NaN   True  False  ...
# 155  840824011   73    0.05  2.3  210.0  1.22  172.0  NaN   True  False  ...
# ..         ...  ...     ...  ...    ...   ...    ...  ...    ...    ...  ...
# 974  841029023   32  150.00  0.4   16.0  0.95   17.0  NaN  False   True  ...
# 979  841029050   30    0.10  3.1  202.0  1.74  116.0  NaN   True  False  ...
# 991  841030049   62    0.10  1.5  198.0  0.94  211.0  NaN   True  False  ...
# 996  841031010   41   53.00  0.4    9.7  1.46    6.6  NaN   True  False  ...
# 998  841031031   20    0.10  0.8  201.0  0.84  240.0  NaN   True  False  ...
#
# ...

# %%
Q3 = df['TBG'].quantile(0.75)
Q1 = df['TBG'].quantile(0.25)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

outliers_TBG =df[(df['TBG'] < lower_bound) | (df['TBG'] > upper_bound)]
outliers_TBG
# Out:
#      Record ID  age  TSH  T3  TT4  T4U  FTI   TBG  sex_F  sex_M  ...  \
# 868  841019084   59  NaN NaN  NaN  NaN  NaN  53.0   True  False  ...
#
#      Condition_M  Condition_MI  Condition_MK  Condition_N  \
# 868        False         False         False        False
#
#      Condition_NO CONDITION  Condition_O  Condition_P  Condition_Q  \
# 868                   False        False        False        False
#
#      Condition_R  Condition_S
# 868        False         True
#
# [1 rows x 79 columns]

# %%
mean = df['age'].mean()
variance = df['age'].var()
print("Mean of age column:", mean)
print("Variance of age column:", variance)
# Out:
# Mean of age column: 51.509
# Variance of age column: 352.5584774774775

# %%
mean = df['TBG'].mean()
variance = df['TBG'].var()
print("Mean of age TBG:", mean)
print("Variance of age TBG:", variance)
# Out:
# Mean of age TBG: 25.526299999
# Variance of age TBG: 2.3028011435961973

# %%
mean = df['T4U'].mean()
variance = df['T4U'].var()
print("Mean of T4U column:", mean)
print("Variance of T4U column:", variance)
# Out:
# Mean of T4U column: 0.9708600000000002
# Variance of T4U column: 0.03864550590590591

# %%
mean = df['FTI'].mean()
variance = df['FTI'].var()
print("Mean of FTI column:", mean)
print("Variance of FTI column:", variance)
# Out:
# Mean of FTI column: 113.758
# Variance of FTI column: 3463.8464024024024

# %%
mean = df['T3'].mean()
variance = df['T3'].var()
print("Mean of T3 column:", mean)
print("Variance of T3 column:", variance)
# Out:
# Mean of T3 column: 1.8177499990000001
# Variance of T3 column: 0.5188562802157167

# %%
mean = df['TT4'].mean()
variance = df['TT4'].var()
print("Mean of TT4 column:", mean)
print("Variance of TT4 column:", variance)
# Out:
# Mean of TT4 column: 106.30980000000001
# Variance of TT4 column: 1669.9514954554554

# %%
mean = df['TSH'].mean()
variance = df['TSH'].var()
print("Mean of TSH column:", mean)
print("Variance of TSH column:", variance)
# Out:
# Mean of TSH column: 5.8972799909999996
# Variance of TSH column: 769.111336237989

# %%
#TSH,T3,T4U,FTI,TT4,TBG CONTAIN OUTLIERS

df['T3'].fillna(df['T3'].median(), inplace=True)
df['T4U'].fillna(df['T4U'].median(), inplace=True)
df['TSH'].fillna(df['TSH'].median(), inplace=True)
df['TBG'].fillna(df['TBG'].median(), inplace=True)
df['FTI'].fillna(df['FTI'].median(), inplace=True)
df['TT4'].fillna(df['TT4'].median(), inplace=True)
df
# Out:
#      Record ID  age   TSH   T3    TT4   T4U    FTI   TBG  sex_F  sex_M  ...  \
# 0    840801013   29   0.3  1.8  103.0  0.96  106.0  25.5   True  False  ...
# 1    840801014   29   1.6  1.9  128.0  0.96  106.0  25.5   True  False  ...
# 2    840801042   41   0.8  1.8  103.0  0.96  106.0  11.0   True  False  ...
# 3    840803046   36   0.8  1.8  103.0  0.96  106.0  26.0   True  False  ...
# 4    840803047   32   0.8  1.8  103.0  0.96  106.0  36.0   True  False  ...
# ..         ...  ...   ...  ...    ...   ...    ...   ...    ...    ...  ...
# 995  841031002   41   0.1  2.1  148.0  1.44  103.0  25.5   True  False  ...
# 996  841031010   41  53.0  0.4    9.7  1.46    6.6  25.5   True  False  ...
# 997  841031030   20   0.8  1.8  103.0  0.96  106.0  30.0   True  False  ...
# 998  841031031   20   0.1  0.8  201.0  0.84  240.0  25.5   True  False  ...
# 999  841031032   73   3.3  1.2   85.0  0.90   94.0  25.5   True  False  ...
#
# ...

# %%
null_counts = df.isna().sum()
print(null_counts)

df.isna().sum().sum()
# Out:
# Record ID        0
# age              0
# TSH            115
# T3             202
# TT4             40
#               ...
# Condition_O      0
# Condition_P      0
# Condition_Q      0
# Condition_R      0
# Condition_S      0
# Length: 79, dtype: int64
# 1517

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scale = ['age','T3','TSH','T4U','TT4','TBG','FTI']
df[scale] = scaler.fit_transform(df[scale])
df
# Out:
#      Record ID       age       TSH        T3       TT4       T4U       FTI  \
# 0    840801013  0.291667  0.000581       NaN       NaN       NaN       NaN
# 1    840801014  0.291667  0.003605  0.216374  0.351124       NaN       NaN
# 2    840801042  0.416667       NaN       NaN       NaN       NaN       NaN
# 3    840803046  0.364583       NaN       NaN       NaN       NaN       NaN
# 4    840803047  0.322917       NaN       NaN       NaN       NaN       NaN
# ..         ...       ...       ...       ...       ...       ...       ...
# 995  841031002  0.416667  0.000116  0.239766  0.407303  0.746988  0.120143
# 996  841031010  0.416667  0.123154  0.040936  0.018820  0.759036  0.004901
# 997  841031030  0.197917       NaN       NaN       NaN       NaN       NaN
# 998  841031031  0.197917  0.000116  0.087719  0.556180  0.385542  0.283921
# 999  841031032  0.750000  0.007559  0.134503  0.230337  0.421687  0.109384
#
# ...

# %%
vector1 = df['sex_M']
vector2 =df['Condition_M']

# Calculate f01, f10, and f11
f00 = ((vector1 == 0) & (vector2 == 0)).sum()
f01 = ((vector1 == 0) & (vector2 == 1)).sum()  
f10 = ((vector1 == 1) & (vector2 == 0)).sum()  
f11 = ((vector1 == 1) & (vector2 == 1)).sum()  
print(f00,f01,f10,f11)

JC = f11 / (f01 + f10 + f11)
SMC = (f11 + f00) / (f00 + f01 + f10 + f11) 


print("Jaccard Coefficient (JC):", JC)
print("Simple Matching Coefficient (SMC):", SMC)
# Out:
# 685 11 301 3
# Jaccard Coefficient (JC): 0.009523809523809525
# Simple Matching Coefficient (SMC): 0.688

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
vector2 = np.array(vector2).reshape(1, -1)
vrctor1 = np.array(vector1).reshape(1, -1)
cosine_sim = cosine_similarity(v1, v2)

print("Cosine Similarity:", cosine_sim)
# Out:
# Cosine Similarity: [[0.04598545]]

# %%
import numpy as np
from sklearn.metrics import jaccard_score
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt


columns_to_extract = df.columns[9:29]
vectors = [df[col] for col in columns_to_extract]

n = len(vectors)
jc_matrix = np.zeros((n, n))
smc_matrix = np.zeros((n, n))
cos_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        jc_matrix[i][j] = jaccard_score(vectors[i], vectors[j])
        smc_matrix[i][j] = np.sum(np.logical_and(vectors[i], vectors[j])) / np.sum(np.logical_or(vectors[i], vectors[j]))
        cos_matrix[i][j] = cosine_similarity([vectors[i]], [vectors[j]])[0][0]


plt.figure(figsize=(12, 4))

plt.subplot(131)
sns.heatmap(jc_matrix, annot=True, cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title('Jaccard Coefficient')

plt.subplot(132)
sns.heatmap(smc_matrix, annot=True, cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title('Simple Matching Coefficient')

plt.subplot(133)
sns.heatmap(cos_matrix, annot=True, cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title('Cosine Similarity')

plt.tight_layout()
plt.show()
